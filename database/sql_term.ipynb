# %%
from database import DATABASE_CONNECTION

# %%
cursor = DATABASE_CONNECTION.cursor

# %%
cursor.execute("Select * FROM MOVIE LIMIT 0")
colnames = [desc[0] for desc in cursor.description]
print(colnames)
# Out:
# ['movie_id', 'movie_title', 'content_rating_id', 'plot', 'year', 'released', 'runtime_mins', 'poster_link', 'language', 'country', 'imdb_rating', 'imdb_votes', 'imdb_id', 'box_office', 'type']
